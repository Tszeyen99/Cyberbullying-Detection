# %%
# !git clone https://github.com/clips/bratreader.git
# !cd bratreader
# !python setup.py install
# Out:
# fatal: destination path 'bratreader' already exists and is not an empty directory.
# /Library/Frameworks/Python.framework/Versions/3.11/Resources/Python.app/Contents/MacOS/Python: can't open file '/Users/tszeyenthen/Python Study/jupyter notebbok/Cyberbullying/fyp/amica-cyberbullying-distribute/setup.py': [Errno 2] No such file or directory

# %%
pip install lxml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 7.9 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install inflect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.2/395.2 kB 3.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 3.4 MB/s eta 0:00:0000:0100:01m
# ...
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install corenlp-xml-reader
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 2.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for corenlp-xml-reader: filename=corenlp_xml_reader-0.1.3-py3-none-any.whl size=1659946 sha256=bdd56838f73187c11e5903bf8be610e40bf92917ca783d813bb0ad2387dfe0a4
#   Stored in directory: /Users/tszeyenthen/Library/Caches/pip/wheels/8f/a1/c8/df492f4ce8586daf51e7d037fc58b1e62dd186e352c103cba7
# Successfully built corenlp-xml-reader
# ...
#
# [notice] A new release of pip is available: 23.3 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install brat-reader
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for brat-reader: filename=brat_reader-0.0.0-py3-none-any.whl size=4277 sha256=4b9d9b6cba44852d8ef9fe6e26943b4b4d53bc87375638a6c28ad61632bacc46
#   Stored in directory: /Users/tszeyenthen/Library/Caches/pip/wheels/ac/a9/e0/cda5977a805683de6a95eaa0049a1b2636af2946c7081ce293
# Successfully built brat-reader
# ...
#
# [notice] A new release of pip is available: 23.3 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from bratreader.repomodel import RepoModel
r = RepoModel("en") # load repomodel

# %%
r.documents
# Out:
# {'Askfm_conversation_2564_main': <bratreader.annotateddocument.AnnotatedDocument at 0x15822f7d0>,
#  'Askfm_conversation_11606_main': <bratreader.annotateddocument.AnnotatedDocument at 0x147fc9490>,
#  'Askfm_conversation_2702_main': <bratreader.annotateddocument.AnnotatedDocument at 0x15905a9d0>,
#  'Askfm_conversation_21363_main': <bratreader.annotateddocument.AnnotatedDocument at 0x1588aed50>,
#  'Askfm_conversation_15408_main': <bratreader.annotateddocument.AnnotatedDocument at 0x29febbdd0>,
#  'Askfm_conversation_21105_main': <bratreader.annotateddocument.AnnotatedDocument at 0x29febbed0>,
#  'Askfm_conversation_12959_main': <bratreader.annotateddocument.AnnotatedDocument at 0x29febbd50>,
#  'Askfm_conversation_14837_main': <bratreader.annotateddocument.AnnotatedDocument at 0x15894ecd0>,
#  'Askfm_conversation_2703_main': <bratreader.annotateddocument.AnnotatedDocument at 0x29fec1750>,
# ...

# %%
doc = r.documents["Askfm_conversation_1_main"] 			# get document with key 001
print(doc.sentences)    			# a list of sentences in document
print(doc.annotations)
# Out:
# [<bratreader.sentence.Sentence object at 0x15b4a5790>, <bratreader.sentence.Sentence object at 0x15b4a7450>, <bratreader.sentence.Sentence object at 0x15b4a7890>, <bratreader.sentence.Sentence object at 0x15b4a7910>, <bratreader.sentence.Sentence object at 0x15b4a8250>, <bratreader.sentence.Sentence object at 0x15b4a8790>, <bratreader.sentence.Sentence object at 0x15b4a8810>, <bratreader.sentence.Sentence object at 0x15b4a9410>, <bratreader.sentence.Sentence object at 0x15b4aa7d0>, <bratreader.sentence.Sentence object at 0x15b4a8710>, <bratreader.sentence.Sentence object at 0x15b4aab50>, <bratreader.sentence.Sentence object at 0x15b4ab110>, <bratreader.sentence.Sentence object at 0x15b4ab1d0>, <bratreader.sentence.Sentence object at 0x15b4b03d0>, <bratreader.sentence.Sentence object at 0x15b4b0d10>, <bratreader.sentence.Sentence object at 0x15b4b0dd0>, <bratreader.sentence.Sentence object at 0x15b4b10d0>, <bratreader.sentence.Sentence object at 0x15b4b2110>, <bratreader.sentence.Sent
# ...

# %%
r.save_xml("xml_folder")
